# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
import numpy as np

# Cargar el archivo Excel
file_path = "COM-MALG-TORREMOLINOS (15).xlsx"  # Asegúrate de colocar la ruta correcta
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías para evitar errores
df = df.fillna("")

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función a cada fila del DataFrame
df_left_aligned = pd.DataFrame(df.apply(shift_row_left, axis=1).to_list(), columns=df.columns)

# Eliminar filas que solo tienen información en la primera columna
df_filtered = df_left_aligned[df_left_aligned.iloc[:, 1:].apply(lambda row: any(row.str.strip() != ""), axis=1)]

# Guardar el archivo con los datos alineados y filtrados
df_filtered.to_excel("COM-MALG-TORREMOLINOS (15).xlsx", index=False)

# %%
import pandas as pd

# Cargar el archivo Excel
file_path = "COM-MALG-BENALMADENA (1).xlsx"  # Reemplaza con el nombre correcto
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías
df = df.fillna("")

# Función para eliminar celdas que contienen "https"
def remove_https(row):
    return ["" if "https" in str(x) else x for x in row]

# Aplicar la función a cada fila
df_cleaned = pd.DataFrame(df.apply(remove_https, axis=1).to_list(), columns=df.columns)

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función para alinear los datos a la izquierda
df_final = pd.DataFrame(df_cleaned.apply(shift_row_left, axis=1).to_list(), columns=df.columns)
# Agregar las columnas "Ciudad", "Área" y "Negocio"
df_final["Ciudad"] = "Malaga"  # Puedes cambiar el valor
df_final["Area"] = "Benalmadena"  # Puedes cambiar el valor
df_final["Negocio"] = "Venta"  # Puedes cambiar el valor
df_final = df_final[~df_final.iloc[:, 0].str.contains("Top", case=False, na=False)]
df_final = df_final.loc[:, df_final.iloc[0].str.strip() != ""]


# Guardar el archivo modificado
df_final.to_excel("COM-MALG-BENALMADENA (1).xlsx", index=False)

# %%
# Cargar el archivo Excel
file_path = "COM-MALG-BENALMADENA (1).xlsx"  # Reemplaza con el nombre correcto
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías
df = df.fillna("")

# Función para eliminar celdas que contienen "https"
def remove_https(row):
    return ["" if "https" in str(x) else x for x in row]

# Aplicar la función a cada fila
df_cleaned = pd.DataFrame(df.apply(remove_https, axis=1).to_list(), columns=df.columns)

df_final = df_final[~df_final.iloc[:, 0].str.contains("Top", case=False, na=False)]


# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función para alinear los datos a la izquierda
df_final = pd.DataFrame(df_cleaned.apply(shift_row_left, axis=1).to_list(), columns=df.columns)

# Eliminar columnas donde la primera fila está vacía
df_final = df_final.loc[:, df_final.iloc[0].str.strip() != ""]


# Agregar las columnas "Ciudad", "Área" y "Negocio"
df_final["Ciudad"] = "Malaga"  # Puedes cambiar el valor
df_final["Area"] = "Benalmadena"  # Puedes cambiar el valor
df_final["Negocio"] = "Venta"  # Puedes cambiar el valor


# Guardar el archivo modificado
output_file = "COM-MALG-BENALMADENA (1)_MODIFICADO.xlsx"
df_final.to_excel(output_file, index=False)

# %%
# Cargar el archivo Excel
file_path = "COM-MALG-BENALMADENA (2).xlsx"  # Reemplaza con el nombre correcto
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías
df = df.fillna("")

# Función para eliminar celdas que contienen "https"
def remove_https(row):
    return ["" if "https" in str(x) else x for x in row]

# Aplicar la función a cada fila
df_cleaned = pd.DataFrame(df.apply(remove_https, axis=1).to_list(), columns=df.columns)

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función para alinear los datos a la izquierda
df_final = pd.DataFrame(df_cleaned.apply(shift_row_left, axis=1).to_list(), columns=df.columns)
# Agregar las columnas "Ciudad", "Área" y "Negocio"
df_final["Ciudad"] = "Malaga"  # Puedes cambiar el valor
df_final["Area"] = "Benalmadena"  # Puedes cambiar el valor
df_final["Negocio"] = "Venta"  # Puedes cambiar el valor
df_final = df_final[~df_final.iloc[:, 0].str.contains("Top", case=False, na=False)]
df_final = df_final.loc[:, df_final.iloc[0].str.strip() != ""]


# Guardar el archivo modificado
df_final.to_excel("COM-MALG-BENALMADENA (2).xlsx", index=False)

# %%
# Cargar el archivo Excel
file_path = "COM-MALG-BENALMADENA (3).xlsx"  # Reemplaza con el nombre correcto
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

df_final = df_final.loc[:, df_final.iloc[0].str.strip() != ""]

# Guardar el archivo modificado
df_final.to_excel("COM-MALG-BENALMADENA (3)1.xlsx", index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 3
#       1 # Cargar el archivo Excel
#       2 file_path = "COM-MALG-BENALMADENA (3).xlsx"  # Reemplaza con el nombre correcto
# ----> 3 df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)
#       5 df_final = df_final.loc[:, df_final.iloc[0].str.strip() != ""]
#       7 # Guardar el archivo modificado
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#     507 try:
# --> 508     data = io.parse(
#     509         sheet_name=sheet_name,
#     510         header=header,
#     511         names=names,
#     512         index_col=index_col,
#     513         usecols=usecols,
#     514         dtype=dtype,
#     515         converters=converters,
#     516         true_values=true_values,
#     517         false_values=false_values,
#     518         skiprows=skiprows,
#     519         nrows=nrows,
#     520         na_values=na_values,
#     521         keep_default_na=keep_default_na,
#     522         na_filter=na_filter,
#     523         verbose=verbose,
#     524         parse_dates=parse_dates,
#     525         date_parser=date_parser,
#     526         date_format=date_format,
#     527         thousands=thousands,
#     528         decimal=decimal,
#     529         comment=comment,
#     530         skipfooter=skipfooter,
#     531         dtype_backend=dtype_backend,
#     532     )
#     533 finally:
#     534     # make sure to close opened file handles
#     535     if should_close:
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_base.py:1616, in ExcelFile.parse(self, sheet_name, header, names, index_col, usecols, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, date_format, thousands, comment, skipfooter, dtype_backend, **kwds)
#    1576 def parse(
#    1577     self,
#    1578     sheet_name: str | int | list[int] | list[str] | None = 0,
#    (...)   1596     **kwds,
#    1597 ) -> DataFrame | dict[str, DataFrame] | dict[int, DataFrame]:
#    1598     """
#    1599     Parse specified sheet(s) into a DataFrame.
#    1600
#    (...)   1614     >>> file.parse()  # doctest: +SKIP
#    1615     """
# -> 1616     return self._reader.parse(
#    1617         sheet_name=sheet_name,
#    1618         header=header,
#    1619         names=names,
#    1620         index_col=index_col,
#    1621         usecols=usecols,
#    1622         converters=converters,
#    1623         true_values=true_values,
#    1624         false_values=false_values,
#    1625         skiprows=skiprows,
#    1626         nrows=nrows,
#    1627         na_values=na_values,
#    1628         parse_dates=parse_dates,
#    1629         date_parser=date_parser,
#    1630         date_format=date_format,
#    1631         thousands=thousands,
#    1632         comment=comment,
#    1633         skipfooter=skipfooter,
#    1634         dtype_backend=dtype_backend,
#    1635         **kwds,
#    1636     )
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_base.py:773, in BaseExcelReader.parse(self, sheet_name, header, names, index_col, usecols, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, dtype_backend, **kwds)
#     770     print(f"Reading sheet {asheetname}")
#     772 if isinstance(asheetname, str):
# --> 773     sheet = self.get_sheet_by_name(asheetname)
#     774 else:  # assume an integer if not a string
#     775     sheet = self.get_sheet_by_index(asheetname)
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_openpyxl.py:582, in OpenpyxlReader.get_sheet_by_name(self, name)
#     581 def get_sheet_by_name(self, name: str):
# --> 582     self.raise_if_bad_sheet_by_name(name)
#     583     return self.book[name]
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_base.py:624, in BaseExcelReader.raise_if_bad_sheet_by_name(self, name)
#     622 def raise_if_bad_sheet_by_name(self, name: str) -> None:
#     623     if name not in self.sheet_names:
# --> 624         raise ValueError(f"Worksheet named '{name}' not found")
#
# ValueError: Worksheet named 'Sheet_1' not found

# %%
# Cargar el archivo Excel
file_path = "COM-MALG-BENALMADENA (4).xlsx"  # Reemplaza con el nombre correcto
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías
df = df.fillna("")

# Función para eliminar celdas que contienen "https"
def remove_https(row):
    return ["" if "https" in str(x) else x for x in row]

# Aplicar la función a cada fila
df_cleaned = pd.DataFrame(df.apply(remove_https, axis=1).to_list(), columns=df.columns)

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función para alinear los datos a la izquierda
df_final = pd.DataFrame(df_cleaned.apply(shift_row_left, axis=1).to_list(), columns=df.columns)
# Agregar las columnas "Ciudad", "Área" y "Negocio"
df_final["Ciudad"] = "Malaga"  # Puedes cambiar el valor
df_final["Area"] = "Benalmadena"  # Puedes cambiar el valor
df_final["Negocio"] = "Venta"  # Puedes cambiar el valor
df_final = df_final[~df_final.iloc[:, 0].str.contains("Top", case=False, na=False)]
df_final = df_final.loc[:, df_final.iloc[0].str.strip() != ""]


# Guardar el archivo modificado
df_final.to_excel("COM-MALG-BENALMADENA (4).xlsx", index=False)

# %%
# Cargar el archivo Excel
file_path = "COM-MALG-BENALMADENA (5).xlsx"  # Reemplaza con el nombre correcto
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías
df = df.fillna("")

# Función para eliminar celdas que contienen "https"
def remove_https(row):
    return ["" if "https" in str(x) else x for x in row]

# Aplicar la función a cada fila
df_cleaned = pd.DataFrame(df.apply(remove_https, axis=1).to_list(), columns=df.columns)

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función para alinear los datos a la izquierda
df_final = pd.DataFrame(df_cleaned.apply(shift_row_left, axis=1).to_list(), columns=df.columns)
# Agregar las columnas "Ciudad", "Área" y "Negocio"
df_final["Ciudad"] = "Malaga"  # Puedes cambiar el valor
df_final["Area"] = "Benalmadena"  # Puedes cambiar el valor
df_final["Negocio"] = "Venta"  # Puedes cambiar el valor
df_final = df_final[~df_final.iloc[:, 0].str.contains("Top", case=False, na=False)]
df_final = df_final.loc[:, df_final.iloc[0].str.strip() != ""]


# Guardar el archivo modificado
df_final.to_excel("COM-MALG-BENALMADENA (5).xlsx", index=False)

# %%
# Cargar el archivo Excel
file_path = "COM-MALG-BENALMADENA (6).xlsx"  # Reemplaza con el nombre correcto
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías
df = df.fillna("")

# Función para eliminar celdas que contienen "https"
def remove_https(row):
    return ["" if "https" in str(x) else x for x in row]

# Aplicar la función a cada fila
df_cleaned = pd.DataFrame(df.apply(remove_https, axis=1).to_list(), columns=df.columns)

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función para alinear los datos a la izquierda
df_final = pd.DataFrame(df_cleaned.apply(shift_row_left, axis=1).to_list(), columns=df.columns)
# Agregar las columnas "Ciudad", "Área" y "Negocio"
df_final["Ciudad"] = "Malaga"  # Puedes cambiar el valor
df_final["Area"] = "Benalmadena"  # Puedes cambiar el valor
df_final["Negocio"] = "Venta"  # Puedes cambiar el valor
df_final = df_final[~df_final.iloc[:, 0].str.contains("Top", case=False, na=False)]
df_final = df_final.loc[:, df_final.iloc[0].str.strip() != ""]


# Guardar el archivo modificado
df_final.to_excel("COM-MALG-BENALMADENA (6).xlsx", index=False)

# %%
# Cargar el archivo Excel
file_path = "COM-MALG-BENALMADENA (1).xlsx"  # Reemplaza con el nombre correcto
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías
df = df.fillna("")

# Función para eliminar celdas que contienen "https"
def remove_https(row):
    return ["" if "https" in str(x) else x for x in row]

# Aplicar la función a cada fila
df_cleaned = pd.DataFrame(df.apply(remove_https, axis=1).to_list(), columns=df.columns)

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función para alinear los datos a la izquierda
df_final = pd.DataFrame(df_cleaned.apply(shift_row_left, axis=1).to_list(), columns=df.columns)
# Agregar las columnas "Ciudad", "Área" y "Negocio"
df_final["Ciudad"] = "Malaga"  # Puedes cambiar el valor
df_final["Area"] = "Benalmadena"  # Puedes cambiar el valor
df_final["Negocio"] = "Venta"  # Puedes cambiar el valor
df_final = df_final[~df_final.iloc[:, 0].str.contains("Top", case=False, na=False)]
df_final = df_final.loc[:, df_final.iloc[0].str.strip() != ""]


# Guardar el archivo modificado
df_final.to_excel("COM-MALG-BENALMADENA (1).xlsx", index=False)

# %%
# Cargar el archivo Excel
file_path = "COM-MALG-BENALMADENA (7).xlsx"  # Reemplaza con el nombre correcto
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías
df = df.fillna("")

# Función para eliminar celdas que contienen "https"
def remove_https(row):
    return ["" if "https" in str(x) else x for x in row]

# Aplicar la función a cada fila
df_cleaned = pd.DataFrame(df.apply(remove_https, axis=1).to_list(), columns=df.columns)

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función para alinear los datos a la izquierda
df_final = pd.DataFrame(df_cleaned.apply(shift_row_left, axis=1).to_list(), columns=df.columns)
# Agregar las columnas "Ciudad", "Área" y "Negocio"
df_final["Ciudad"] = "Malaga"  # Puedes cambiar el valor
df_final["Area"] = "Benalmadena"  # Puedes cambiar el valor
df_final["Negocio"] = "Venta"  # Puedes cambiar el valor
df_final = df_final[~df_final.iloc[:, 0].str.contains("Top", case=False, na=False)]
df_final = df_final[~df_final.iloc[:, 0].str.contains("Destacado", case=False, na=False)]
df_final = df_final.loc[:, df_final.iloc[0].str.strip() != ""]


# Guardar el archivo modificado
df_final.to_excel("COM-MALG-BENALMADENA (7)1.xlsx", index=False)

# %%
# Cargar el archivo Excel
file_path = "COM-MALG-BENALMADENA (16).xlsx"  # Reemplaza con el nombre correcto
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías
df = df.fillna("")

# Función para eliminar celdas que contienen "https"
def remove_https(row):
    return ["" if "https" in str(x) else x for x in row]

# Aplicar la función a cada fila
df_cleaned = pd.DataFrame(df.apply(remove_https, axis=1).to_list(), columns=df.columns)

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función para alinear los datos a la izquierda
df_final = pd.DataFrame(df_cleaned.apply(shift_row_left, axis=1).to_list(), columns=df.columns)
# Agregar las columnas "Ciudad", "Área" y "Negocio"
df_final["Ciudad"] = "Malaga"  # Puedes cambiar el valor
df_final["Area"] = "Benalmadena"  # Puedes cambiar el valor
df_final["Negocio"] = "Venta"  # Puedes cambiar el valor
df_final = df_final[~df_final.iloc[:, 0].str.contains("Destacado", case=False, na=False)]
df_final = df_final.loc[:, df_final.iloc[0].str.strip() != ""]


# Guardar el archivo modificado
df_final.to_excel("COM-MALG-BENALMADENA (16).xlsx", index=False)

# %%
# Cargar el archivo Excel
file_path = "COM-MALG-CIUDAD (7).xlsx"  # Reemplaza con el nombre correcto
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías
df = df.fillna("")

# Función para eliminar celdas que contienen "https"
def remove_https(row):
    return ["" if "https" in str(x) else x for x in row]

# Aplicar la función a cada fila
df_cleaned = pd.DataFrame(df.apply(remove_https, axis=1).to_list(), columns=df.columns)

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función para alinear los datos a la izquierda
df_final = pd.DataFrame(df_cleaned.apply(shift_row_left, axis=1).to_list(), columns=df.columns)
# Agregar las columnas "Ciudad", "Área" y "Negocio"
df_final["Ciudad"] = "Malaga"  # Puedes cambiar el valor
df_final["Area"] = "Ciudad"  # Puedes cambiar el valor
df_final["Negocio"] = "Venta"  # Puedes cambiar el valor
df_final = df_final[~df_final.iloc[:, 0].str.contains("Top", case=False, na=False)]
df_final = df_final.loc[:, df_final.iloc[0].str.strip() != ""]


# Guardar el archivo modificado
df_final.to_excel("COM-MALG-CIUDAD (7).xlsx", index=False)

# %%
# Cargar el archivo Excel
file_path = "COM-MALG-CIUDAD (56).xlsx"  # Reemplaza con el nombre correcto
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías
df = df.fillna("")

# Función para eliminar celdas que contienen "https"
def remove_https(row):
    return ["" if "https" in str(x) else x for x in row]

# Aplicar la función a cada fila
df_cleaned = pd.DataFrame(df.apply(remove_https, axis=1).to_list(), columns=df.columns)

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función para alinear los datos a la izquierda
df_final = pd.DataFrame(df_cleaned.apply(shift_row_left, axis=1).to_list(), columns=df.columns)
# Agregar las columnas "Ciudad", "Área" y "Negocio"
df_final["Ciudad"] = "Malaga"  # Puedes cambiar el valor
df_final["Area"] = "Ciudad"  # Puedes cambiar el valor
df_final["Negocio"] = "Venta"  # Puedes cambiar el valor
df_final = df_final[~df_final.iloc[:, 0].str.contains("Destacado", case=False, na=False)]
df_final = df_final.loc[:, df_final.iloc[0].str.strip() != ""]


# Guardar el archivo modificado
df_final.to_excel("COM-MALG-CIUDAD (56).xlsx", index=False)

# %%
# Cargar el archivo Excel
file_path = "COM-MALG-TORREMOLINOS (14).xlsx"  # Reemplaza con el nombre correcto
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías
df = df.fillna("")

# Función para eliminar celdas que contienen "https"
def remove_https(row):
    return ["" if "https" in str(x) else x for x in row]

# Aplicar la función a cada fila
df_cleaned = pd.DataFrame(df.apply(remove_https, axis=1).to_list(), columns=df.columns)

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función para alinear los datos a la izquierda
df_final = pd.DataFrame(df_cleaned.apply(shift_row_left, axis=1).to_list(), columns=df.columns)
# Agregar las columnas "Ciudad", "Área" y "Negocio"
df_final["Ciudad"] = "Malaga"  # Puedes cambiar el valor
df_final["Area"] = "Torremolinos"  # Puedes cambiar el valor
df_final["Negocio"] = "Venta"  # Puedes cambiar el valor
df_final = df_final[~df_final.iloc[:, 0].str.contains("Top", case=False, na=False)]
df_final = df_final[~df_final.iloc[:, 0].str.contains("Destacado", case=False, na=False)]
df_final = df_final.loc[:, df_final.iloc[0].str.strip() != ""]


# Guardar el archivo modificado
df_final.to_excel("COM-MALG-TORREMOLINOS (14).xlsx", index=False)
