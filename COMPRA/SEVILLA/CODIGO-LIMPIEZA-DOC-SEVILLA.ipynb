# %%
import pandas as pd

# Cargar el archivo Excel
file_path = "COM-SEV-ALJ1.xlsx"  # Reemplaza con la ruta de tu archivo
df = pd.read_excel(file_path)

# Eliminar filas completamente vacías
df_clean = df.dropna(how="all")

# Guardar el archivo limpio
df_clean.to_excel("COM-SEV-ALJ1.xlsx", index=False)

# %%
import pandas as pd
import numpy as np

# Cargar el archivo Excel
file_path = "COM-SEV-ALJ2.xlsx"  # Reemplaza con la ruta de tu archivo
df = pd.read_excel(file_path, sheet_name="Sheet1", dtype=str)

# Reemplazar NaN por cadenas vacías para evitar errores
df = df.fillna("")

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función a cada fila del DataFrame
df_left_aligned = pd.DataFrame(df.apply(shift_row_left, axis=1).to_list(), columns=df.columns)

# Guardar el archivo con los datos alineados a la izquierda
df_left_aligned.to_excel("COM-SEV-ALJ2-alineado.xlsx", index=False)

# %%
import pandas as pd
import numpy as np

# Cargar el archivo Excel
file_path = "COM-SEV-ALJ3.xlsx"  # Asegúrate de colocar la ruta correcta
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías para evitar errores
df = df.fillna("")

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función a cada fila del DataFrame
df_left_aligned = pd.DataFrame(df.apply(shift_row_left, axis=1).to_list(), columns=df.columns)

# Eliminar filas que solo tienen información en la primera columna
df_filtered = df_left_aligned[df_left_aligned.iloc[:, 1:].apply(lambda row: any(row.str.strip() != ""), axis=1)]

# Guardar el archivo con los datos alineados y filtrados
df_filtered.to_excel("COM-SEV-ALJ3.xlsx", index=False)

# %%
import pandas as pd
import numpy as np

# Cargar el archivo Excel
file_path = "COM-SEV-ALJ4.xlsx"  # Asegúrate de colocar la ruta correcta
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías para evitar errores
df = df.fillna("")

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función a cada fila del DataFrame
df_left_aligned = pd.DataFrame(df.apply(shift_row_left, axis=1).to_list(), columns=df.columns)

# Eliminar filas que solo tienen información en la primera columna
df_filtered = df_left_aligned[df_left_aligned.iloc[:, 1:].apply(lambda row: any(row.str.strip() != ""), axis=1)]

# Guardar el archivo con los datos alineados y filtrados
df_filtered.to_excel("COM-SEV-ALJ4.xlsx", index=False)

# %%
import pandas as pd
import numpy as np

# Cargar el archivo Excel
file_path = "COM-SEV-ALJ5.xlsx"  # Asegúrate de colocar la ruta correcta
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías para evitar errores
df = df.fillna("")

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función a cada fila del DataFrame
df_left_aligned = pd.DataFrame(df.apply(shift_row_left, axis=1).to_list(), columns=df.columns)

# Eliminar filas que solo tienen información en la primera columna
df_filtered = df_left_aligned[df_left_aligned.iloc[:, 1:].apply(lambda row: any(row.str.strip() != ""), axis=1)]

# Guardar el archivo con los datos alineados y filtrados
df_filtered.to_excel("COM-SEV-ALJ5.xlsx", index=False)

# %%
import pandas as pd
import numpy as np

# Cargar el archivo Excel
file_path = "COM-SEV-ALJ6.xlsx"  # Asegúrate de colocar la ruta correcta
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías para evitar errores
df = df.fillna("")

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función a cada fila del DataFrame
df_left_aligned = pd.DataFrame(df.apply(shift_row_left, axis=1).to_list(), columns=df.columns)

# Eliminar filas que solo tienen información en la primera columna
df_filtered = df_left_aligned[df_left_aligned.iloc[:, 1:].apply(lambda row: any(row.str.strip() != ""), axis=1)]

# Guardar el archivo con los datos alineados y filtrados
df_filtered.to_excel("COM-SEV-ALJ6.xlsx", index=False)

# %%
import pandas as pd
import numpy as np

# Cargar el archivo Excel
file_path = "COM-SEV-ALJ7.xlsx"  # Asegúrate de colocar la ruta correcta
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías para evitar errores
df = df.fillna("")

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función a cada fila del DataFrame
df_left_aligned = pd.DataFrame(df.apply(shift_row_left, axis=1).to_list(), columns=df.columns)

# Eliminar filas que solo tienen información en la primera columna
df_filtered = df_left_aligned[df_left_aligned.iloc[:, 1:].apply(lambda row: any(row.str.strip() != ""), axis=1)]

# Guardar el archivo con los datos alineados y filtrados
df_filtered.to_excel("COM-SEV-ALJ7.xlsx", index=False)

# %%
import pandas as pd
import numpy as np

# Cargar el archivo Excel
file_path = "COM-SEV-ALJ8.xlsx"  # Asegúrate de colocar la ruta correcta
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías para evitar errores
df = df.fillna("")

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función a cada fila del DataFrame
df_left_aligned = pd.DataFrame(df.apply(shift_row_left, axis=1).to_list(), columns=df.columns)

# Eliminar filas que solo tienen información en la primera columna
df_filtered = df_left_aligned[df_left_aligned.iloc[:, 1:].apply(lambda row: any(row.str.strip() != ""), axis=1)]

# Guardar el archivo con los datos alineados y filtrados
df_filtered.to_excel("COM-SEV-ALJ8.xlsx", index=False)

# %%
import pandas as pd
import numpy as np

# Cargar el archivo Excel
file_path = "COM-SEV-AMETRO1.xlsx"  # Asegúrate de colocar la ruta correcta
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías para evitar errores
df = df.fillna("")

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función a cada fila del DataFrame
df_left_aligned = pd.DataFrame(df.apply(shift_row_left, axis=1).to_list(), columns=df.columns)

# Eliminar filas que solo tienen información en la primera columna
df_filtered = df_left_aligned[df_left_aligned.iloc[:, 1:].apply(lambda row: any(row.str.strip() != ""), axis=1)]

# Guardar el archivo con los datos alineados y filtrados
df_filtered.to_excel("COM-SEV-AMETRO1.xlsx", index=False)

# %%
import pandas as pd
import numpy as np

# Cargar el archivo Excel
file_path = "COM-SEV-AMETRO2.xlsx"  # Asegúrate de colocar la ruta correcta
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías para evitar errores
df = df.fillna("")

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función a cada fila del DataFrame
df_left_aligned = pd.DataFrame(df.apply(shift_row_left, axis=1).to_list(), columns=df.columns)

# Eliminar filas que solo tienen información en la primera columna
df_filtered = df_left_aligned[df_left_aligned.iloc[:, 1:].apply(lambda row: any(row.str.strip() != ""), axis=1)]

# Guardar el archivo con los datos alineados y filtrados
df_filtered.to_excel("COM-SEV-AMETRO2.xlsx", index=False)

# %%
import pandas as pd
import numpy as np

# Cargar el archivo Excel
file_path = "COM-SEV-AMETRO3.xlsx"  # Asegúrate de colocar la ruta correcta
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías para evitar errores
df = df.fillna("")

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función a cada fila del DataFrame
df_left_aligned = pd.DataFrame(df.apply(shift_row_left, axis=1).to_list(), columns=df.columns)

# Eliminar filas que solo tienen información en la primera columna
df_filtered = df_left_aligned[df_left_aligned.iloc[:, 1:].apply(lambda row: any(row.str.strip() != ""), axis=1)]

# Guardar el archivo con los datos alineados y filtrados
df_filtered.to_excel("COM-SEV-AMETRO3.xlsx", index=False)

# %%
import pandas as pd
import numpy as np

# Cargar el archivo Excel
file_path = "COM-SEV-AMETRO4.xlsx"  # Asegúrate de colocar la ruta correcta
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías para evitar errores
df = df.fillna("")

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función a cada fila del DataFrame
df_left_aligned = pd.DataFrame(df.apply(shift_row_left, axis=1).to_list(), columns=df.columns)

# Eliminar filas que solo tienen información en la primera columna
df_filtered = df_left_aligned[df_left_aligned.iloc[:, 1:].apply(lambda row: any(row.str.strip() != ""), axis=1)]

# Guardar el archivo con los datos alineados y filtrados
df_filtered.to_excel("COM-SEV-AMETRO4.xlsx", index=False)

# %%
import pandas as pd
import numpy as np

# Cargar el archivo Excel
file_path = "COM-SEV-AMETRO5.xlsx"  # Asegúrate de colocar la ruta correcta
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías para evitar errores
df = df.fillna("")

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función a cada fila del DataFrame
df_left_aligned = pd.DataFrame(df.apply(shift_row_left, axis=1).to_list(), columns=df.columns)

# Eliminar filas que solo tienen información en la primera columna
df_filtered = df_left_aligned[df_left_aligned.iloc[:, 1:].apply(lambda row: any(row.str.strip() != ""), axis=1)]

# Guardar el archivo con los datos alineados y filtrados
df_filtered.to_excel("COM-SEV-AMETRO5.xlsx", index=False)

# %%
import pandas as pd
import numpy as np

# Cargar el archivo Excel
file_path = "COM-SEV-AMETRO6.xlsx"  # Asegúrate de colocar la ruta correcta
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías para evitar errores
df = df.fillna("")

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función a cada fila del DataFrame
df_left_aligned = pd.DataFrame(df.apply(shift_row_left, axis=1).to_list(), columns=df.columns)

# Eliminar filas que solo tienen información en la primera columna
df_filtered = df_left_aligned[df_left_aligned.iloc[:, 1:].apply(lambda row: any(row.str.strip() != ""), axis=1)]

# Guardar el archivo con los datos alineados y filtrados
df_filtered.to_excel("COM-SEV-AMETRO6.xlsx", index=False)

# %%
import pandas as pd
import numpy as np

# Cargar el archivo Excel
file_path = "COM-SEV-CIUDAD1.xlsx"  # Asegúrate de colocar la ruta correcta
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías para evitar errores
df = df.fillna("")

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función a cada fila del DataFrame
df_left_aligned = pd.DataFrame(df.apply(shift_row_left, axis=1).to_list(), columns=df.columns)

# Eliminar filas que solo tienen información en la primera columna
df_filtered = df_left_aligned[df_left_aligned.iloc[:, 1:].apply(lambda row: any(row.str.strip() != ""), axis=1)]

# Guardar el archivo con los datos alineados y filtrados
df_filtered.to_excel("COM-SEV-CIUDAD1.xlsx", index=False)

# %%
import pandas as pd
import numpy as np

# Cargar el archivo Excel
file_path = "COM-SEV-CIUDAD2.xlsx"  # Asegúrate de colocar la ruta correcta
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías para evitar errores
df = df.fillna("")

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función a cada fila del DataFrame
df_left_aligned = pd.DataFrame(df.apply(shift_row_left, axis=1).to_list(), columns=df.columns)

# Eliminar filas que solo tienen información en la primera columna
df_filtered = df_left_aligned[df_left_aligned.iloc[:, 1:].apply(lambda row: any(row.str.strip() != ""), axis=1)]

# Guardar el archivo con los datos alineados y filtrados
df_filtered.to_excel("COM-SEV-CIUDAD2.xlsx", index=False)

# %%
import pandas as pd
import numpy as np

# Cargar el archivo Excel
file_path = "COM-SEV-CIUDAD3.xlsx"  # Asegúrate de colocar la ruta correcta
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías para evitar errores
df = df.fillna("")

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función a cada fila del DataFrame
df_left_aligned = pd.DataFrame(df.apply(shift_row_left, axis=1).to_list(), columns=df.columns)

# Eliminar filas que solo tienen información en la primera columna
df_filtered = df_left_aligned[df_left_aligned.iloc[:, 1:].apply(lambda row: any(row.str.strip() != ""), axis=1)]

# Guardar el archivo con los datos alineados y filtrados
df_filtered.to_excel("COM-SEV-CIUDAD3.xlsx", index=False)

# %%
import pandas as pd
import numpy as np

# Cargar el archivo Excel
file_path = "COM-SEV-CIUDAD4.xlsx"  # Asegúrate de colocar la ruta correcta
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías para evitar errores
df = df.fillna("")

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función a cada fila del DataFrame
df_left_aligned = pd.DataFrame(df.apply(shift_row_left, axis=1).to_list(), columns=df.columns)

# Eliminar filas que solo tienen información en la primera columna
df_filtered = df_left_aligned[df_left_aligned.iloc[:, 1:].apply(lambda row: any(row.str.strip() != ""), axis=1)]

# Guardar el archivo con los datos alineados y filtrados
df_filtered.to_excel("COM-SEV-CIUDAD4.xlsx", index=False)

# %%
import pandas as pd
import numpy as np

# Cargar el archivo Excel
file_path = "COM-SEV-CIUDAD5.xlsx"  # Asegúrate de colocar la ruta correcta
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías para evitar errores
df = df.fillna("")

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función a cada fila del DataFrame
df_left_aligned = pd.DataFrame(df.apply(shift_row_left, axis=1).to_list(), columns=df.columns)

# Eliminar filas que solo tienen información en la primera columna
df_filtered = df_left_aligned[df_left_aligned.iloc[:, 1:].apply(lambda row: any(row.str.strip() != ""), axis=1)]

# Guardar el archivo con los datos alineados y filtrados
df_filtered.to_excel("COM-SEV-CIUDAD5.xlsx", index=False)

# %%
import pandas as pd
import numpy as np

# Cargar el archivo Excel
file_path = "COM-SEV-CIUDAD6.xlsx"  # Asegúrate de colocar la ruta correcta
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías para evitar errores
df = df.fillna("")

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función a cada fila del DataFrame
df_left_aligned = pd.DataFrame(df.apply(shift_row_left, axis=1).to_list(), columns=df.columns)

# Eliminar filas que solo tienen información en la primera columna
df_filtered = df_left_aligned[df_left_aligned.iloc[:, 1:].apply(lambda row: any(row.str.strip() != ""), axis=1)]

# Guardar el archivo con los datos alineados y filtrados
df_filtered.to_excel("COM-SEV-CIUDAD6.xlsx", index=False)

# %%
import pandas as pd
import numpy as np

# Cargar el archivo Excel
file_path = "COM-SEV-CIUDAD7.xlsx"  # Asegúrate de colocar la ruta correcta
df = pd.read_excel(file_path, sheet_name="Sheet_1", dtype=str)

# Reemplazar NaN por cadenas vacías para evitar errores
df = df.fillna("")

# Función para mover datos a la izquierda fila por fila
def shift_row_left(row):
    values = [x for x in row if x.strip() != ""]  # Filtrar valores vacíos
    empty_count = len(row) - len(values)  # Contar cuántos valores vacíos se eliminaron
    return values + [""] * empty_count  # Rellenar con espacios vacíos al final

# Aplicar la función a cada fila del DataFrame
df_left_aligned = pd.DataFrame(df.apply(shift_row_left, axis=1).to_list(), columns=df.columns)

# Eliminar filas que solo tienen información en la primera columna
df_filtered = df_left_aligned[df_left_aligned.iloc[:, 1:].apply(lambda row: any(row.str.strip() != ""), axis=1)]

# Guardar el archivo con los datos alineados y filtrados
df_filtered.to_excel("COM-SEV-CIUDAD7.xlsx", index=False)
